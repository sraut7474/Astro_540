# %%
from classy import Class
import numpy as np
import matplotlib.pyplot as plt

# %%
# create instance of the class "Class"
LambdaCDM = Class()
# pass input parameters
LambdaCDM.set({'omega_b':0.0223828,'omega_cdm':0.1201075,'h':0.67810,'A_s':2.100549e-09,'n_s':0.9660499,'tau_reio':0.05430842})
LambdaCDM.set({'output':'tCl,pCl,lCl,mPk','lensing':'yes','P_k_max_1/Mpc':3.0})
# run class
LambdaCDM.compute()

# %%
# get P(k) at redhsift z=0
kk = np.logspace(-4,np.log10(3),1000) # k in h/Mpc
Pk1 = [] # P(k) in (Mpc/h)**3
h = LambdaCDM.h() # get reduced Hubble for conversions to 1/Mpc
for k in kk:
    Pk1.append(LambdaCDM.pk(k*h,0.)*h**3) # function .pk(k,z)

# %%
# plot P(k)
plt.figure(2)
plt.xscale('log');plt.yscale('log');plt.xlim(kk[0],kk[-1])
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')
plt.plot(kk,Pk1,'b-')

# %%
# create instance of the class "Class"
LambdaCDM = Class()
omb=0.0223828
omc=0.1201075
omtot=omb+omc
x=.95
omc=x*omtot
omb=(1-x)*omtot
# pass input parameters
LambdaCDM.set({'omega_b':omb,'omega_cdm':omc,'h':0.67810,'A_s':2.100549e-09,'n_s':0.9660499,'tau_reio':0.05430842})
LambdaCDM.set({'output':'tCl,pCl,lCl,mPk','lensing':'yes','P_k_max_1/Mpc':3.0})
# run class
LambdaCDM.compute()

# %%
# get P(k) at redhsift z=0
kk = np.logspace(-4,np.log10(3),1000) # k in h/Mpc
Pk = [] # P(k) in (Mpc/h)**3
h = LambdaCDM.h() # get reduced Hubble for conversions to 1/Mpc
for k in kk:
    Pk.append(LambdaCDM.pk(k*h,0.)*h**3) # function .pk(k,z)

# %%
# plot P(k)
plt.figure(2)
plt.xscale('log');plt.yscale('log');plt.xlim(kk[0],kk[-1])
plt.xlabel(r'$k \,\,\,\, [h/\mathrm{Mpc}]$')
plt.ylabel(r'$P(k) \,\,\,\, [\mathrm{Mpc}/h]^3$')
plt.plot(kk,Pk,'b-',label='Model 2')
plt.plot(kk,Pk1,label='Model 1')
plt.legend()
plt.savefig("Astr540HW4compproblem")

# %%
# create instance of the class "Class"
LambdaCDM = Class()
omb=0.0223828
omc=0.1201075
omb=omb+(.99*omc)
omc=(.01*omc)
# pass input parameters
LambdaCDM.set({'omega_b':omb,'omega_cdm':omc,'h':0.67810,'A_s':2.100549e-09,'n_s':0.9660499,'tau_reio':0.05430842})
LambdaCDM.set({'output':'tCl,pCl,lCl,mPk','lensing':'yes','P_k_max_1/Mpc':3.0})
# run class
LambdaCDM.compute()
# Out:
# ---------------------------------------------------------------------------
# CosmoComputationError                     Traceback (most recent call last)
# Input In [26], in <cell line: 11>()
#       9 LambdaCDM.set({'output':'tCl,pCl,lCl,mPk','lensing':'yes','P_k_max_1/Mpc':3.0})
#      10 # run class
# ---> 11 LambdaCDM.compute()
#
# File classy.pyx:389, in classy.Class.compute()
#
# CosmoComputationError:
#
# Error in Class: thermodynamics_init(L:342) :error in thermodynamics_helium_from_bbn(ppr,pba,pth);
# =>thermodynamics_helium_from_bbn(L:612) :condition (omega_b > omegab[num_omegab-1]) is true; You have asked for an unrealistic high value omega_b = 1.412892e-01. The corresponding value of the primordial helium fraction cannot be found in the interpolation table. If you really want this value, you should fix YHe to a given value rather than to BBN
